# %%
import numpy as np
from collections import Counter
import json, os, shutil

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.set(font='Avenir', style='white')

# %%
size = 1e5
dir = 'simulate_' + str(int(size)) + '/'

with open(dir + 'profile.json') as f:
    data = json.load(f)

# %%
dists = sorted(list(set(data.keys()) - set(['ps'])))

# %%
fig = plt.figure(figsize=(16,6))

i = 0
for dist in dists:
    i += 1
    ax = fig.add_subplot(1,3,i)
    
    for algorithm,speeds in data[dist]['speed'].iteritems():
        ax.plot(speeds, data['ps'], label=algorithm)
    ax.set_title(dist)
    ax.set_xlabel('speed')
    ax.set_ylabel('percentile')
    ax.legend(loc=2)

plt.suptitle('percentile speed', size=20)
plt.tight_layout()
plt.subplots_adjust(top=0.85)

plt.savefig(dir + 'profiles.png', dpi=300)
# Out:
# /Users/lily-chai/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'Avenir'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
